# %% [markdown]
# >> maybe..
#
# >> reset the index here, 'order' can be the index
#
# >> turn all the names to fit a particular case
#
# >> arrange the heights in ascending/descending
#
# >> do different kinds of stats on this
#
# >> plot different findings
#
# >> how many presidents have common names and stuff
#
# >> try lots of visualisations on this.

# %%
import pandas as pd
import numpy as np

# %%
heights = pd.read_csv('height.csv')

# %%
#method chaining

def tweak_heights(df):
    return(heights
   .set_index('order')
   .assign(name = heights
           .name
           .astype('string')
           .str
           .lower()
          )
    .sort_values(
           by=["height(cm)"],
           ignore_index= True
         )
            )

# %%
tweak_heights(heights)
# Out:
#                       name  height(cm)
# 0             james monroe         163
# 1   william henry harrison         168
# 2       theodore roosevelt         168
# 3         thomas jefferson         170
# 4           woodrow wilson         170
# 5           andrew jackson         171
# 6               john tyler         173
# 7           zachary taylor         173
# 8         millard fillmore         173
# 9      rutherford b. hayes         173
# 10       james a. garfield         174
# 11         franklin pierce         175
# 12       lyndon b. johnson         175
# 13            bill clinton         177
# 14        ulysses s. grant         178
# 15          james buchanan         178
# 16       warren g. harding         178
# 17         harry s. truman         178
# 18           richard nixon         179
# 19          herbert hoover         180
# 20                    <NA>         182
# 21    dwight d. eisenhower         182
# 22           ronald reagan         182
# ...

# %%
heights.describe()
# Out:
#            order  height(cm)
# count  42.000000   42.000000
# mean   22.476190  179.738095
# std    13.152461    7.015869
# min     1.000000  163.000000
# 25%    11.250000  174.250000
# 50%    22.000000  182.000000
# 75%    33.750000  183.000000
# max    44.000000  193.000000

# %%
height = np.array(heights["height(cm)"])
print('mean height=',height.mean())
print('median height=',np.median(height))
print('minimum height=',height.min())
print('maximum height=',height.max())
print('standard deviation=',height.std())
print('25th percentile=',np.percentile(height,25))
print('75th percentile=',np.percentile(height,75))
# Out:
# mean height= 179.73809523809524
# median height= 182.0
# minimum height= 163
# maximum height= 193
# standard deviation= 6.931843442745892
# 25th percentile= 174.25
# 75th percentile= 183.0

# %%
heights["height(cm)"].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
heights["height(cm)"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# learn to read and interpret the boxplot
# understand distribution, skew, kde and what to conclude from those numbers
# there are some missing names
# check for duplicates
# create a word cloud
